# %%
try:
    a=10
    b=0
    c=a/b
    print(c)
except:
     print("something is not right")
# Out:
# something is not right

# %%
#EG compile time error(syntax error)
#syntax error :
if 1==0
print(0)
# Out:
#   Cell In[2], line 3
#     if 1==0
#            ^
# SyntaxError: expected ':'

# %%
# #syntax error  ""
print("hello)

# syntax error )
# print("Hello")
# Out:
#   Cell In[5], line 2
#     print("hello)
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
#EG runtime error (type error)
t=(1,2,3,4)
t[0]=100
print(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 #EG runtime error (type error)
#       2 t=(1,2,3,4)
# ----> 3 t[0]=100
#       4 print(t)
#       6 #EG runtime error (indentation error)
#       7 # if 1==0:
#       8 # print(1)
#
# TypeError: 'tuple' object does not support item assignment

# %%
#EG runtime error (indentation error)
if 1==0:
print(1)
# Out:
#   Cell In[4], line 3
#     print(1)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
#zerodivisonerror
try:
    a=10
    b=2
    c=a/b
    print(c)
except :
     print("Something is wrong")
# Out:
# 5.0

# %%
try:
     a=10
     b=0
     c=a/b
     print(c)
except ZeroDivisionError:
     print("Zero division is not possible")
except:
    print("Something else is wrong")
# Out:
# Zero division is not possible

# %%
try:
    a=10
    c=a+"hi"
    print(c)
except ZeroDivisionError:
    print("Zero division is not possible")
except:
    print("Something else is wrong")
# Out:
# Something else is wrong
