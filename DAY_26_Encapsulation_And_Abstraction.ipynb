# %%
# encapsulation - keeps all attributes and methods in a single unit, that is, a class. 
# The main aim of encapsulation is to restrict the direct access of class methods(attributes + methods)

# %%
# The restriction of access by using access modifiers
# public  -  we don't implement _
# protected - start with _
# private - start with __

# %%
class Bank:
    bank_name = "Codegnan Bank"
    def __init__(self, username, password, amount):
        self.username = username  # public
        self._password = password  # protected
        self.__amount = amount  # private
    def balance(self):
        return f'Current Balance is {self.__amount}'
    def withdraw(self, withdraw_amount):
        if self.__amount >= withdraw_amount:
            self.__amount -= withdraw_amount
            return f'{withdraw_amount} withdrawal successfull and current balance is {self.__amount}'
        return "Insufficent Funds"
    def deposite(self, deposite_amount):
        self.__amount += deposit_amount
        return f'{deposite_amount} Deposite successful and current balance is {self.__amount}'
    def __total_users(self):   # private method
        return "Bank Total users are 98"

user = Bank('srinu@123', "Babu@1234", 2000)
print(user.balance())
print(user.withdraw(500))
print(user._password)
# name mangling
print(user._Bank__amount)
# Out:
# Current Balance is 2000
# 500 withdrawal successfull and current balance is 1500
# Babu@1234
# 1500

# %%
# abstraction
# abstraction means hiding the function implementation and showing the function declaration
# abstract methods not implemented 
# With the help of the abc module, we can implement abstract.
# abc abstract base class 
# abc has one abstract class - starts with @ and has only function declarations without implementation
# abstract method implementation present in the child class
